# %%
import pyspark
from pyspark.sql.functions import explode, col
from delta.pip_utils import configure_spark_with_delta_pip

# %%
spark = pyspark.sql.SparkSession.builder \
    .appName('Lab9') \
    .config('spark.driver.extraClassPath', '/opt/sqljdbc_4.2/enu/jre8/sqljdbc42.jar') \
    .config('spark.executor.extraClassPath', '/opt/sqljdbc_4.2/enu/jre8/sqljdbc42.jar') \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \

spark = configure_spark_with_delta_pip(spark).getOrCreate()

# %% [markdown]
# #### Spark server is accessible here (click on Spark UI):

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Dell-Vostro:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Lab9</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
def display_head(df: pyspark.sql.DataFrame, n: int):
    return df.limit(n).toPandas().head(n)

# %%
df = spark.read \
      .format("json") \
      .option("multiline", "true") \
      .load("Nested.json")

# %%
df = df.select('*', 'pathLinkInfo.*').drop('pathLinkInfo').select('*', 'elevationGain.*').drop('elevationGain')

# %%
display_head(df, 2)
# Out:
#            CaptureDate  CaptureID               FID Geometry  \
# 0  2020-12-31T00:00:00          3  24b3sdf4353fc220   Geo223
#
#            attribute1 changeType_source  identifier alternateName  \
# 0  Under Construction            insert           2          None
#
#   captureSpecification cycleFacility  ...  \
# 0                Urban          None  ...
#
#                         formsPartOfStreet heightingMethod  matchStatus  \
# 0  [4fb3afad-2c56-4946-83d1-d734508705e2]             DTM      Matched
#
#   pathName   sourceFID startGradeSeparation  \
# 0     None  MissingFID                    0
#
#                              startNode        surfaceType  \
# 0  147b7a78-04bf-4f9a-801d-61dc534a0a5  Sealed on surface
#
#   elevationAgainstDirection elevationInDirection
# 0                       1.3                    0
#
# [1 rows x 25 columns]

# %%
df.columns
# Out:
# ['CaptureDate',
#  'CaptureID',
#  'FID',
#  'Geometry',
#  'attribute1',
#  'changeType_source',
#  'identifier',
#  'alternateName',
#  'captureSpecification',
#  'cycleFacility',
#  'endGradeSeparation',
#  'endNode',
#  'fictitious',
#  'formOfWay',
#  'formsPartOfPath',
#  'formsPartOfStreet',
#  'heightingMethod',
#  'matchStatus',
#  'pathName',
#  'sourceFID',
#  'startGradeSeparation',
#  'startNode',
#  'surfaceType',
#  'elevationAgainstDirection',
#  'elevationInDirection']

# %%
df = df.drop("attribute1", "endGradeSeparation", "elevationAgainstDirection","formsPartOfPath" )

# %%
df.columns
# Out:
# ['CaptureDate',
#  'CaptureID',
#  'FID',
#  'Geometry',
#  'changeType_source',
#  'identifier',
#  'alternateName',
#  'captureSpecification',
#  'cycleFacility',
#  'endNode',
#  'fictitious',
#  'formOfWay',
#  'formsPartOfStreet',
#  'heightingMethod',
#  'matchStatus',
#  'pathName',
#  'sourceFID',
#  'startGradeSeparation',
#  'startNode',
#  'surfaceType',
#  'elevationInDirection']

# %%
display_head(df, 2)
# Out:
#            CaptureDate  CaptureID               FID Geometry  \
# 0  2020-12-31T00:00:00          3  24b3sdf4353fc220   Geo223
#
#   changeType_source  identifier alternateName captureSpecification  \
# 0            insert           2          None                Urban
#
#   cycleFacility                                endNode  ...  formOfWay  \
# 0          None  eb7f6122-f765-4113-8b77-908934437ee96  ...       Path
#
#                         formsPartOfStreet heightingMethod matchStatus  \
# 0  [4fb3afad-2c56-4946-83d1-d734508705e2]             DTM     Matched
#
#   pathName   sourceFID startGradeSeparation  \
# 0     None  MissingFID                    0
#
#                              startNode        surfaceType elevationInDirection
# 0  147b7a78-04bf-4f9a-801d-61dc534a0a5  Sealed on surface                    0
#
# [1 rows x 21 columns]

# %%
### No foldLeft in python - there is no need to use one if there would be a need to use sth like this we can call functools.reduce or itertools.accumulate

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load("online-retail-dataset.csv")

# %%
display_head(df, 30)
# Out:
#    InvoiceNo StockCode                          Description Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1     536365     71053                  WHITE METAL LANTERN        6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES        2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER        6
# 7     536366     22633               HAND WARMER UNION JACK        6
# 8     536366     22632            HAND WARMER RED POLKA DOT        6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT       32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM         6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN        6
# 12    536367     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL        8
# 13    536367     22310              IVORY KNITTED MUG COSY         6
# 14    536367     84969   BOX OF 6 ASSORTED COLOUR TEASPOONS        6
# 15    536367     22623        BOX OF VINTAGE JIGSAW BLOCKS         3
# 16    536367     22622       BOX OF VINTAGE ALPHABET BLOCKS        2
# 17    536367     21754             HOME BUILDING BLOCK WORD        3
# 18    536367     21755             LOVE BUILDING BLOCK WORD        3
# 19    536367     21777          RECIPE BOX WITH METAL HEART        4
# 20    536367     48187                  DOORMAT NEW ENGLAND        4
# 21    536368     22960             JAM MAKING SET WITH JARS        6
# 22    536368     22913          RED COAT RACK PARIS FASHION        3
# 23    536368     22912       YELLOW COAT RACK PARIS FASHION        3
# 24    536368     22914         BLUE COAT RACK PARIS FASHION        3
# 25    536369     21756             BATH BUILDING BLOCK WORD        3
# 26    536370     22728            ALARM CLOCK BAKELIKE PINK       24
# 27    536370     22727            ALARM CLOCK BAKELIKE RED        24
# 28    536370     22726           ALARM CLOCK BAKELIKE GREEN       12
# 29    536370     21724      PANDA AND BUNNIES STICKER SHEET       12
#
#        InvoiceDate UnitPrice CustomerID         Country
# 0   12/1/2010 8:26      2.55      17850  United Kingdom
# 1   12/1/2010 8:26      3.39      17850  United Kingdom
# 2   12/1/2010 8:26      2.75      17850  United Kingdom
# 3   12/1/2010 8:26      3.39      17850  United Kingdom
# 4   12/1/2010 8:26      3.39      17850  United Kingdom
# 5   12/1/2010 8:26      7.65      17850  United Kingdom
# 6   12/1/2010 8:26      4.25      17850  United Kingdom
# 7   12/1/2010 8:28      1.85      17850  United Kingdom
# 8   12/1/2010 8:28      1.85      17850  United Kingdom
# 9   12/1/2010 8:34      1.69      13047  United Kingdom
# 10  12/1/2010 8:34       2.1      13047  United Kingdom
# 11  12/1/2010 8:34       2.1      13047  United Kingdom
# 12  12/1/2010 8:34      3.75      13047  United Kingdom
# 13  12/1/2010 8:34      1.65      13047  United Kingdom
# 14  12/1/2010 8:34      4.25      13047  United Kingdom
# 15  12/1/2010 8:34      4.95      13047  United Kingdom
# 16  12/1/2010 8:34      9.95      13047  United Kingdom
# 17  12/1/2010 8:34      5.95      13047  United Kingdom
# 18  12/1/2010 8:34      5.95      13047  United Kingdom
# 19  12/1/2010 8:34      7.95      13047  United Kingdom
# 20  12/1/2010 8:34      7.95      13047  United Kingdom
# 21  12/1/2010 8:34      4.25      13047  United Kingdom
# 22  12/1/2010 8:34      4.95      13047  United Kingdom
# 23  12/1/2010 8:34      4.95      13047  United Kingdom
# 24  12/1/2010 8:34      4.95      13047  United Kingdom
# 25  12/1/2010 8:35      5.95      13047  United Kingdom
# 26  12/1/2010 8:45      3.75      12583          France
# 27  12/1/2010 8:45      3.75      12583          France
# 28  12/1/2010 8:45      3.75      12583          France
# 29  12/1/2010 8:45      0.85      12583          France

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("maxRecordsPerFile", 100) \
    .save('./delta')
# Out:
# 23/06/24 19:50:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:13 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:16 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:17 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:19 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:19 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:19 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:50:19 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:50:20 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
from time import perf_counter
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(spark, './delta')

t0 = perf_counter()
num_records = delta_table.toDF().count()
t1 = perf_counter()
print(f'Number of records: {num_records} time before optimization: {t1-t0 :.4f} s')

delta_table.optimize()

t0 = perf_counter()
num_records = delta_table.toDF().count()
t1 = perf_counter()
print(f'Number of records: {num_records} time after optimization: {t1-t0 :.4f} s')
# Out:
# Number of records: 541909 time before optimization: 0.2281 s
# Number of records: 541909 time after optimization: 0.2561 s

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("zOrderBy", "Country") \
    .save('./delta_zordered')
# Out:
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 23/06/24 19:59:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")
delta_table.vacuum(0)
# Out:
# Deleted 83 files and directories in a total of 1 directories.
# DataFrame[]
